# %% [markdown]
# # はじめに：統計学と機械学習

# %% [markdown]
# ## 0.「はじめに」を始める前に
# ## 1.標準的統計学－記述統計学と推測統計学－
# ### 記述統計学
# ### 推測統計学
# ## 2.標準的機械学習
# ### よく使われる手法
# ### 機械が学習する？
# ### 機械が学習しているのは何か？
# ### EDA
# ### 主成分分析
# ## 3.ベイズ統計学：「真実は常に一つ」か？
